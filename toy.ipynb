# %%
metrics = {
    "chamfer_distance": 0.46342308286929723,
    "ate": 0.18974357979831674,
    "are": 4.35080972136567,
    "rpe_rot": 0.8637775710488218,
    "rpe_trans": 0.03759400013899647,
    "inference_time_ms": 672007.5048816447
}

rounded_metrics = {k: round(v, 3) for k, v in metrics.items()}

print(rounded_metrics)
